# %% [markdown]
# <a href="https://colab.research.google.com/github/Zopek/2019F-CSIT5210/blob/master/tutorial_1_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![img_0.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# $ ax^2+bx+c=0$
